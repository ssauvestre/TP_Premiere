# %%
# Définition d'une liste vide
L1=[]
# Définition d'une liste contenant trois éléments
L2=[17.6,3,"blabla"]
# Affichage des deux listes
print(L1)
print(L2)

# Affichage du premier élément de la liste (d'indice zéro)
print (L2[0])
# Affichage du deuxième élément de la liste (d'indice zéro)
print (L2[1])

# Somme puis affichage des deux premiers éléments de la liste
S = L2[0]+L2[1]
print (S)

# Obtenir la longueur de la liste (sa taille, le nombre d'élements qu'elle contient) : fonction len
n = len(L2)
print(n)

# Ajout d'un élément à un liste : par concaténation
L1 = L1 + [22]
# Ajout d'un élément à une liste : grâce à la mathode append
L2.append(19)
# Affichage des listes ainsi modifiées
print(L1)
print(L2)
print(len(L2))

# Calculer et afficher la somme des nombres contenus dans L2
